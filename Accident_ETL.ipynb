# %%
# Import dependencies
import os
import pandas as pd
import numpy
import psycopg2
from sqlalchemy import create_engine
from config import username, password
import time

# %%
# Import the data
file_path = "resources/US_Accidents_June20.csv"
accident_df = pd.read_csv(file_path)
accident_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
for column in accident_df.columns:
    print(f"Column {column} has {accident_df[column].isnull().sum()} null values")
# Out:
# Column ID has 0 null values
# Column Source has 0 null values
# Column TMC has 1034799 null values
# Column Severity has 0 null values
# Column Start_Time has 0 null values
# Column End_Time has 0 null values
# Column Start_Lat has 0 null values
# Column Start_Lng has 0 null values
# Column End_Lat has 2478818 null values
# Column End_Lng has 2478818 null values
# Column Distance(mi) has 0 null values
# Column Description has 1 null values
# Column Number has 2262864 null values
# Column Street has 0 null values
# Column Side has 0 null values
# Column City has 112 null values
# Column County has 0 null values
# Column State has 0 null values
# Column Zipcode has 1069 null values
# Column Country has 0 null values
# Column Timezone has 3880 null values
# Column Airport_Code has 6758 null values
# Column Weather_Timestamp has 43323 null values
# Column Temperature(F) has 65732 null values
# Column Wind_Chill(F) has 1868249 null values
# Column Humidity(%) has 69687 null values
# Column Pressure(in) has 55882 null values
# Column Visibility(mi) has 75856 null values
# Column Wind_Direction has 58874 null values
# Column Wind_Speed(mph) has 454609 null values
# Column Precipitation(in) has 2025874 null values
# Column Weather_Condition has 76138 null values
# Column Amenity has 0 null values
# Column Bump has 0 null values
# Column Crossing has 0 null values
# Column Give_Way has 0 null values
# Column Junction has 0 null values
# Column No_Exit has 0 null values
# Column Railway has 0 null values
# Column Roundabout has 0 null values
# Column Station has 0 null values
# Column Stop has 0 null values
# Column Traffic_Calming has 0 null values
# Column Traffic_Signal has 0 null values
# Column Turning_Loop has 0 null values
# Column Sunrise_Sunset has 115 null values
# Column Civil_Twilight has 115 null values
# Column Nautical_Twilight has 115 null values
# Column Astronomical_Twilight has 115 null values

# %%
accident_dropna_df = accident_df.dropna(subset=['Zipcode', 'Temperature(F)', 'Weather_Condition'])

# %%
new_accident_df = accident_dropna_df.drop(['ID', 'Source', 'TMC', 'End_Time', 'Airport_Code', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Wind_Chill(F)', 'Wind_Direction', 'Humidity(%)', 'Pressure(in)', 'Description', 'Number', 'Street', 'Side', 'City', 'County', 'Timezone', 'Weather_Timestamp', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'], axis=1)
new_accident_df.head()
# Out:
#    Severity           Start_Time  Start_Lat  Start_Lng State     Zipcode  \
# 0         3  2016-02-08 05:46:00  39.865147 -84.058723    OH       45424
# 1         2  2016-02-08 06:07:59  39.928059 -82.831184    OH  43068-3402
# 2         2  2016-02-08 06:49:27  39.063148 -84.032608    OH       45176
# 3         3  2016-02-08 07:23:34  39.747753 -84.205582    OH       45417
# 4         2  2016-02-08 07:39:07  39.627781 -84.188354    OH       45459
#
#   Country  Temperature(F)  Visibility(mi)  Wind_Speed(mph)  ...  Give_Way  \
# 0      US            36.9            10.0              NaN  ...     False
# 1      US            37.9            10.0              NaN  ...     False
# 2      US            36.0            10.0              3.5  ...     False
# 3      US            35.1             9.0              4.6  ...     False
# 4      US            36.0             6.0              3.5  ...     False
#
#   Junction  No_Exit  Railway  Roundabout  Station   Stop  Traffic_Calming  \
# 0    False    False    False       False    False  False            False
# 1    False    False    False       False    False  False            False
# 2    False    False    False       False    False  False            False
# 3    False    False    False       False    False  False            False
# 4    False    False    False       False    False  False            False
#
#    Traffic_Signal  Turning_Loop
# 0           False         False
# 1           False         False
# 2            True         False
# 3           False         False
# 4            True         False
#
# [5 rows x 25 columns]

# %%
new_accident_df.dtypes
# Out:
# Severity               int64
# Start_Time            object
# Start_Lat            float64
# Start_Lng            float64
# State                 object
# Zipcode               object
# Country               object
# Temperature(F)       float64
# Visibility(mi)       float64
# Wind_Speed(mph)      float64
# Precipitation(in)    float64
# Weather_Condition     object
# Amenity                 bool
# Bump                    bool
# Crossing                bool
# Give_Way                bool
# Junction                bool
# No_Exit                 bool
# Railway                 bool
# Roundabout              bool
# Station                 bool
# Stop                    bool
# Traffic_Calming         bool
# Traffic_Signal          bool
# Turning_Loop            bool
# dtype: object

# %%
# Convert Start_Time to datetypes
new_accident_df['Start_Time'] = pd.to_datetime(new_accident_df['Start_Time'], errors='coerce')

# %%
# Extract year, month, day, hour, and weekday
new_accident_df['Year'] = new_accident_df['Start_Time'].dt.year
new_accident_df['Month'] = new_accident_df['Start_Time'].dt.strftime('%B')
new_accident_df['Time'] = new_accident_df['Start_Time'].dt.strftime("%I:%M %p")
new_accident_df['Part_of_Week'] = new_accident_df['Start_Time'].dt.strftime('%a')

# %%
new_accident_df = new_accident_df.fillna(0)

# %%
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Mon', 'Weekday')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Tue', 'Weekday')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Wed', 'Weekday')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Thu', 'Weekday')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Fri', 'Weekday')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Sat', 'Weekend')
new_accident_df['Part_of_Week'] = new_accident_df['Part_of_Week'].str.replace('Sun', 'Weekend')

# %%
new_accident_df
# Out:
#          Severity          Start_Time  Start_Lat   Start_Lng State  \
# 0               3 2016-02-08 05:46:00  39.865147  -84.058723    OH
# 1               2 2016-02-08 06:07:59  39.928059  -82.831184    OH
# 2               2 2016-02-08 06:49:27  39.063148  -84.032608    OH
# 3               3 2016-02-08 07:23:34  39.747753  -84.205582    OH
# 4               2 2016-02-08 07:39:07  39.627781  -84.188354    OH
# ...           ...                 ...        ...         ...   ...
# 3513612         2 2019-08-23 18:03:25  34.002480 -117.379360    CA
# 3513613         2 2019-08-23 19:11:30  32.766960 -117.148060    CA
# 3513614         2 2019-08-23 19:00:21  33.775450 -117.847790    CA
# 3513615         2 2019-08-23 19:00:21  33.992460 -118.403020    CA
# 3513616         2 2019-08-23 18:52:06  34.133930 -117.230920    CA
#
#             Zipcode Country  Temperature(F)  Visibility(mi)  Wind_Speed(mph)  \
# 0             45424      US            36.9            10.0              0.0
# 1        43068-3402      US            37.9            10.0              0.0
# 2             45176      US            36.0            10.0              3.5
# 3             45417      US            35.1             9.0              4.6
# 4             45459      US            36.0             6.0              3.5
# ...             ...     ...             ...             ...              ...
# 3513612       92501      US            86.0            10.0             13.0
# 3513613       92108      US            70.0            10.0              6.0
# 3513614       92866      US            73.0            10.0             10.0
# 3513615       90230      US            71.0            10.0              8.0
# 3513616       92346      US            79.0             7.0              7.0
#
#          ...  Roundabout Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0        ...       False   False  False            False           False
# 1        ...       False   False  False            False           False
# 2        ...       False   False  False            False            True
# 3        ...       False   False  False            False           False
# 4        ...       False   False  False            False            True
# ...      ...         ...     ...    ...              ...             ...
# 3513612  ...       False   False  False            False           False
# 3513613  ...       False   False  False            False           False
# 3513614  ...       False   False  False            False           False
# 3513615  ...       False   False  False            False           False
# 3513616  ...       False   False  False            False           False
#
#          Turning_Loop  Year     Month      Time  Part_of_Week
# 0               False  2016  February  05:46 AM       Weekday
# 1               False  2016  February  06:07 AM       Weekday
# 2               False  2016  February  06:49 AM       Weekday
# 3               False  2016  February  07:23 AM       Weekday
# 4               False  2016  February  07:39 AM       Weekday
# ...               ...   ...       ...       ...           ...
# 3513612         False  2019    August  06:03 PM       Weekday
# 3513613         False  2019    August  07:11 PM       Weekday
# 3513614         False  2019    August  07:00 PM       Weekday
# 3513615         False  2019    August  07:00 PM       Weekday
# 3513616         False  2019    August  06:52 PM       Weekday
#
# [3425450 rows x 29 columns]

# %%
cleaned_df = new_accident_df.drop(['Start_Time', 'Amenity', 'Station'], axis=1)

# %%
cleaned_df
# Out:
#          Severity  Start_Lat   Start_Lng State     Zipcode Country  \
# 0               3  39.865147  -84.058723    OH       45424      US
# 1               2  39.928059  -82.831184    OH  43068-3402      US
# 2               2  39.063148  -84.032608    OH       45176      US
# 3               3  39.747753  -84.205582    OH       45417      US
# 4               2  39.627781  -84.188354    OH       45459      US
# ...           ...        ...         ...   ...         ...     ...
# 3513612         2  34.002480 -117.379360    CA       92501      US
# 3513613         2  32.766960 -117.148060    CA       92108      US
# 3513614         2  33.775450 -117.847790    CA       92866      US
# 3513615         2  33.992460 -118.403020    CA       90230      US
# 3513616         2  34.133930 -117.230920    CA       92346      US
#
#          Temperature(F)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 0                  36.9            10.0              0.0               0.02
# 1                  37.9            10.0              0.0               0.00
# 2                  36.0            10.0              3.5               0.00
# 3                  35.1             9.0              4.6               0.00
# 4                  36.0             6.0              3.5               0.00
# ...                 ...             ...              ...                ...
# 3513612            86.0            10.0             13.0               0.00
# 3513613            70.0            10.0              6.0               0.00
# 3513614            73.0            10.0             10.0               0.00
# 3513615            71.0            10.0              8.0               0.00
# 3513616            79.0             7.0              7.0               0.00
#
#          ... Railway  Roundabout   Stop  Traffic_Calming  Traffic_Signal  \
# 0        ...   False       False  False            False           False
# 1        ...   False       False  False            False           False
# 2        ...   False       False  False            False            True
# 3        ...   False       False  False            False           False
# 4        ...   False       False  False            False            True
# ...      ...     ...         ...    ...              ...             ...
# 3513612  ...   False       False  False            False           False
# 3513613  ...   False       False  False            False           False
# 3513614  ...   False       False  False            False           False
# 3513615  ...   False       False  False            False           False
# 3513616  ...   False       False  False            False           False
#
#          Turning_Loop  Year     Month      Time  Part_of_Week
# 0               False  2016  February  05:46 AM       Weekday
# 1               False  2016  February  06:07 AM       Weekday
# 2               False  2016  February  06:49 AM       Weekday
# 3               False  2016  February  07:23 AM       Weekday
# 4               False  2016  February  07:39 AM       Weekday
# ...               ...   ...       ...       ...           ...
# 3513612         False  2019    August  06:03 PM       Weekday
# 3513613         False  2019    August  07:11 PM       Weekday
# 3513614         False  2019    August  07:00 PM       Weekday
# 3513615         False  2019    August  07:00 PM       Weekday
# 3513616         False  2019    August  06:52 PM       Weekday
#
# [3425450 rows x 26 columns]

# %%
cleaned_df.rename(columns = {'Start_Lat':'Latitude', 'Start_Lng':'Longitude', 'Wind_Speed(mph)': 'Wind Speed(mph)',
                              'Weather_Condition':'Weather Condition', 'Bump': 'Speed Bump', 'Crossing': 'Cross Walk',
                               'Give_Way': 'Yield Sign', 'Junction': 'Intersection', 'No_Exit': 'No Exit', 'Stop': 'Stop Sign',
                               'Traffic_Calming': 'Traffic', 'Traffic_Signal': 'Traffic Light', 'Turning_Loop': 'Turning Loop',
                                'Part_of_Week': 'Part of Week'}, inplace = True)

# %%
cleaned_df
# Out:
#          Severity   Latitude   Longitude State     Zipcode Country  \
# 0               3  39.865147  -84.058723    OH       45424      US
# 1               2  39.928059  -82.831184    OH  43068-3402      US
# 2               2  39.063148  -84.032608    OH       45176      US
# 3               3  39.747753  -84.205582    OH       45417      US
# 4               2  39.627781  -84.188354    OH       45459      US
# ...           ...        ...         ...   ...         ...     ...
# 3513612         2  34.002480 -117.379360    CA       92501      US
# 3513613         2  32.766960 -117.148060    CA       92108      US
# 3513614         2  33.775450 -117.847790    CA       92866      US
# 3513615         2  33.992460 -118.403020    CA       90230      US
# 3513616         2  34.133930 -117.230920    CA       92346      US
#
#          Temperature(F)  Visibility(mi)  Wind Speed(mph)  Precipitation(in)  \
# 0                  36.9            10.0              0.0               0.02
# 1                  37.9            10.0              0.0               0.00
# 2                  36.0            10.0              3.5               0.00
# 3                  35.1             9.0              4.6               0.00
# 4                  36.0             6.0              3.5               0.00
# ...                 ...             ...              ...                ...
# 3513612            86.0            10.0             13.0               0.00
# 3513613            70.0            10.0              6.0               0.00
# 3513614            73.0            10.0             10.0               0.00
# 3513615            71.0            10.0              8.0               0.00
# 3513616            79.0             7.0              7.0               0.00
#
#          ... Railway  Roundabout  Stop Sign  Traffic  Traffic Light  \
# 0        ...   False       False      False    False          False
# 1        ...   False       False      False    False          False
# 2        ...   False       False      False    False           True
# 3        ...   False       False      False    False          False
# 4        ...   False       False      False    False           True
# ...      ...     ...         ...        ...      ...            ...
# 3513612  ...   False       False      False    False          False
# 3513613  ...   False       False      False    False          False
# 3513614  ...   False       False      False    False          False
# 3513615  ...   False       False      False    False          False
# 3513616  ...   False       False      False    False          False
#
#          Turning Loop  Year     Month      Time  Part of Week
# 0               False  2016  February  05:46 AM       Weekday
# 1               False  2016  February  06:07 AM       Weekday
# 2               False  2016  February  06:49 AM       Weekday
# 3               False  2016  February  07:23 AM       Weekday
# 4               False  2016  February  07:39 AM       Weekday
# ...               ...   ...       ...       ...           ...
# 3513612         False  2019    August  06:03 PM       Weekday
# 3513613         False  2019    August  07:11 PM       Weekday
# 3513614         False  2019    August  07:00 PM       Weekday
# 3513615         False  2019    August  07:00 PM       Weekday
# 3513616         False  2019    August  06:52 PM       Weekday
#
# [3425450 rows x 26 columns]

# %%
# Create the output file (CSV)
output_data_file = "Resources/Cleaned_Accidents_Data.csv"
cleaned_df.to_csv(output_data_file, index=False)
